# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/My\ Drive/PRML-2020/Data\ Contest
# Out:
# /content/drive/My Drive/PRML-2020/Data Contest

# %%
import os
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
import pickle as pkl
from sklearn.decomposition import PCA

# %% [markdown]
# # Biker going/not going

# %%
tour_convoy = pd.read_csv('./dataset/tour_convoy.csv')
tour_convoy.index = tour_convoy['tour_id']
tour_convoy.drop(['tour_id'], axis=1, inplace=True)
tours_dict = tour_convoy.index
display(tour_convoy)
# Out:
#                                                         going  ...              not_going
# tour_id                                                        ...
# QQ59822043  BJ75964455 CF2302513 EC26086795 DI05886383 BE2...  ...  DF75574655 BA77296663
# VX6467261   CD94228942 CG86116898 BA56558062 DH92942231 EB...  ...                    NaN
# QQ86208412                                                NaN  ...  BH28988561 CJ50720854
# RV21578336                                                NaN  ...                    NaN
# XU5842686   CE06118796 DF50897984 CJ4255260 BB25817077 BA9...  ...             DF00235232
# ...                                                       ...  ...                    ...
# QQ0980591                                                 NaN  ...                    NaN
# UX2973300   CH64820512 FH535535 DI52680355 BF52352413 BJ22...  ...             DI95101160
# QR94481466  EB97808605 CB09654543 BE11365919 DD12623074 CI...  ...             DF21355909
# ...

# %%
bikers_dict = pkl.load(open('./Required Data/bikers_list.pkl', 'rb'))
tours_dict = pkl.load(open('./Required Data/tours_list.pkl', 'rb'))

# %%
biker_tours = np.zeros((len(bikers_dict.keys()), len(tours_dict.keys())))
for tour_id in tqdm(tours_dict.keys()):
    going = tour_convoy.loc[tour_id]['going']
    not_going = tour_convoy.loc[tour_id]['not_going']
    maybe = tour_convoy.loc[tour_id]['maybe']

    try:
        going = going.split()
        for biker_id in going:
            try:
                biker_tours[bikers_dict[biker_id], tours_dict[tour_id]] = 1
            except:
                continue
    except:
        continue

    try:
        not_going = not_going.split()
        for biker_id in not_going:
            try:
                biker_tours[bikers_dict[biker_id], tours_dict[tour_id]] = -1
            except:
                continue
    except:
        continue

    try:
        maybe = maybe.split()
        for biker_id in maybe:
            try:
                biker_tours[bikers_dict[biker_id], tours_dict[tour_id]] = 0.5
            except:
                continue
    except:
        continue

# %%
tour_biker_data = pd.DataFrame(data=biker_tours, index=bikers_dict.keys(), columns=tours_dict.keys())
display(tour_biker_data)
# Out:
#             QQ59822043  VX6467261  ...  RR52745757  QQ87086028
# DB97468391         0.0        0.0  ...         0.0         0.0
# DF37982273         0.0        0.0  ...         0.0         0.0
# IC3183725          0.0        0.0  ...         0.0         0.0
# BI72223848         0.0        0.0  ...         0.0         0.0
# DE29017717         0.0        0.0  ...         0.0         0.0
# ...                ...        ...  ...         ...         ...
# EA64394129         0.0        0.0  ...         0.0         0.0
# EE6388078          0.0        0.0  ...         0.0         0.0
# CF48659919         0.0        0.0  ...         0.0         0.0
# HC3239978          0.0        0.0  ...         0.0         0.0
# BC5781176          0.0        0.0  ...         0.0         0.0
#
# [38209 rows x 24144 columns]

# %%
tour_biker_data.to_csv('./Required data/tour-biker.csv')
